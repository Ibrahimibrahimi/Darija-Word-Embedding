# %% [markdown]
# # Word2Vec — Moroccan Dialect
# Train, embed, and predict — run cells in order.

# %%
from model import train, embed_dataset, predict_next_word
from model import test_vocab, test_similar, test_predict

# %% [markdown]
# ## Step 1 — Train
# Reads `data/global.txt` and saves weights to `model/`.

# %%
train()
# Out:
# Device: cpu
# Sentences: 5
# Vocab: 121 | Pairs: 1626
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train()
#
# File c:\Users\ibrahim-pfe\Desktop\Machine Learning\WORKS\PROJECT\Machine learning - Word2Vec in darija\2\ML_PROJECT_WORD2VEC\model\train.py:122, in train(data_path)
#     120 loader = DataLoader(_PairDataset(pairs), batch_size=BATCH_SIZE, shuffle=True)
#     121 model  = SkipGram(len(w2i), EMBED_DIM).to(device)
# --> 122 opt    = optim.Adam(model.parameters(), lr=LR)
#     124 for epoch in range(1, EPOCHS + 1):
#     125     total = 0
#
# File c:\Users\ibrahim-pfe\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\optim\adam.py:102, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused, decoupled_weight_decay)
# ...

# %% [markdown]
# ## Step 2 — Embed Dataset
# Converts all sentences to vectors. Saves to `data/embedding.csv`.

# %%
embed_dataset()

# %% [markdown]
# Preview the embedding CSV.

# %%
import pandas as pd
df = pd.read_csv('data/embedding.csv')
print(df.shape)
df.head()

# %% [markdown]
# ## Step 3 — Predict Next Words

# %%
predict_next_word('ana machi', length=5)

# %% [markdown]
# ## Tests

# %%
test_vocab()

# %%
test_similar('zwina', top_k=5)

# %%
test_predict('wach nta mzyan', length=5)
